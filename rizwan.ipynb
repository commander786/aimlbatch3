# %%
#install libraries 
# %pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
x=np.array([4,8,5])
y=np.array([7,8,7])
plt.plot(x,y, marker="o")
plt.show()

# %%
x=np.array([4,4,5])
y=np.array([4,4,6])
plt.plot(x,y,marker=".")
plt.show()

# %%
x= np.array([0,6])
y= np.array([0,250])
plt.plot(x,y,marker="+")
plt.show()

# %%
x= np.array([0,6])
y= np.array([0,250])
plt.plot(x,y,marker="v")
plt.show()

# %%
x= np.array([0,6])
y= np.array([0,250])
plt.plot(x,y,marker=">")
plt.show()

# %%
x= np.array([0,6])
y= np.array([0,250])
plt.plot(x,y,marker="_")
plt.show()

# %%
x= np.array([0,6])
y= np.array([0,250])
plt.plot(x,y,marker="<")
plt.show()

# %%
x= np.array([0,6,65])
y= np.array([0,250,67])
plt.plot(x,y,marker="s")
plt.show()

# %%
x= np.array([0,6])
y= np.array([0,250])
plt.plot(x,y,marker="d")
plt.show()

# %%
x= np.array([0,6,4])
y= np.array([0,250,6])
plt.plot(x,y,marker="h")
plt.show()

# %%
x= np.array([0,6,9])
y= np.array([0,250,160])
plt.plot(x,y,marker="v")
plt.show()

# %%
x= np.array([0,6,7])
y= np.array([0,250,7])
plt.plot(x,y,marker="*")
plt.show()

# %%
xy=np.array([65,150,8])
yx=np.array([67,15,7])
plt.plot(xy,yx,marker="*")
plt.show()

# %%
yr=np.array([165,78,87])
ry=np.array([87,87,90])
plt.plot(yr,ry,marker="*")
plt.show()
